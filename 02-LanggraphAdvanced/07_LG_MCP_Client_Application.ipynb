# %% [markdown]
# # MCP Client Application
#
# In this tutorial, we build a LangGraph **agent that consumes tools from an MCP server over HTTP**, instead of defining tools locally.
#
# The MCP server (`MCP_Server/server.py`) exposes three tools:
#
# * `add(a, b)` — combines two numbers
# * `get-energy-prices` — fetches tomorrow's energy prices from a public API
# * `get-todos` — fetches a public todo list
#
# We'll use [`langchain-mcp-adapters`](https://github.com/langchain-ai/langchain-mcp-adapters) to discover those tools over the `streamable-http` transport and hand them to a LangGraph ReAct-style agent, exactly like we bound local Python functions as tools in `03_LG_Bedrock_agent.ipynb`.
#
# **Before running this notebook**, start the MCP server in a separate terminal:
#
# ```bash
# cd 02-LanggraphAdvanced/MCP_Server
# pip install -r requirements.txt
# python server.py
# ```
#
# It should print `MCP server running at http://localhost:3000`.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_aws langchain_core langgraph langgraph-prebuilt langchain-mcp-adapters load_dotenv

# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["AWS_ACCESS_KEY_ID"] = os.getenv('AWS_ACCESS_KEY_ID')
os.environ["AWS_SECRET_ACCESS_KEY"] = os.getenv('AWS_SECRET_ACCESS_KEY')
os.environ["AWS_DEFAULT_REGION"] = os.getenv('AWS_DEFAULT_REGION')

# %% [markdown]
# We'll use [LangSmith](https://docs.smith.langchain.com/) for [tracing](https://docs.smith.langchain.com/concepts/tracing).

# %%
os.environ["LANGSMITH_API_KEY"] = os.getenv('LANGSMITH_API_KEY')
os.environ["LANGSMITH_ENDPOINT"]="https://api.smith.langchain.com"
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "tutorial"

# %% [markdown]
# ## Connect to the MCP server
#
# `MultiServerMCPClient` can talk to one or many MCP servers at once, each identified by a name. We only have `server.py` running locally, exposed over `streamable_http` at `http://localhost:3000/mcp` (matching `.vscode/mcp.json`).
#
# `client.get_tools()` opens a session, calls `list_tools`, and wraps every remote tool as a LangChain `BaseTool` we can bind straight to a model — no manual JSON-RPC handling required.

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

mcp_client = MultiServerMCPClient(
    {
        "ness_mcp_server": {
            "url": "http://localhost:3000/mcp",
            "transport": "streamable_http",
        }
    }
)

tools = await mcp_client.get_tools()
for tool in tools:
    print(f"{tool.name}: {tool.description}")

# %% [markdown]
# ## Bind the MCP tools to a model
#
# Same pattern as the local-tools agent: bind the discovered tools to `ChatBedrock` and let the model decide when to call them.

# %%
from langchain_aws import ChatBedrockConverse

llm = ChatBedrockConverse(
    model_id="amazon.nova-pro-v1:0",
    temperature=0,
    max_tokens=None,
)
llm_with_tools = llm.bind_tools(tools)

# %%
from langgraph.graph import MessagesState
from langchain_core.messages import HumanMessage, SystemMessage

sys_msg = SystemMessage(
    content="You are a helpful assistant. Use the available MCP tools whenever they can answer the question."
)

# Node
def assistant(state: MessagesState):
    return {"messages": [llm_with_tools.invoke([sys_msg] + state["messages"])]}

# %% [markdown]
# ## Build the graph
#
# As before: an `assistant` node (the model with tools bound) and a `tools` node (a `ToolNode` that executes whichever tool call the model requested). `tools_condition` routes to `tools` when the model asked for a tool call, and to `END` otherwise; the edge from `tools` back to `assistant` lets the model use the tool result to keep reasoning or produce a final answer.

# %%
from langgraph.graph import START, StateGraph
from langgraph.prebuilt import ToolNode, tools_condition
from langgraph.checkpoint.memory import MemorySaver
from IPython.display import Image, display

builder = StateGraph(MessagesState)

builder.add_node("assistant", assistant)
builder.add_node("tools", ToolNode(tools))

builder.add_edge(START, "assistant")
builder.add_conditional_edges("assistant", tools_condition)
builder.add_edge("tools", "assistant")

memory = MemorySaver()
mcp_graph = builder.compile(checkpointer=memory)

try:
    display(Image(mcp_graph.get_graph().draw_mermaid_png()))
except Exception:
    print(mcp_graph.get_graph().draw_ascii())

# %% [markdown]
# ## Try it out
#
# Each call below routes through `assistant` → `tools` (an MCP tool call over HTTP) → `assistant` again for the final answer.
#
# > Note: the server's `add` tool currently multiplies its two inputs (see `server.py`) rather than adding them — the response below reflects that, not a bug in this notebook.

# %%
config = {"configurable": {"thread_id": "mcp-demo-1"}}

result = await mcp_graph.ainvoke(
    {"messages": [HumanMessage(content="Use the add tool on 3 and 4, then tell me the result.")]},
    config=config,
)
for m in result["messages"]:
    m.pretty_print()

# %% [markdown]
# ## Interactive chat loop
#
# The graph is async because the MCP tool calls go over HTTP, so the interactive loop uses `ainvoke` instead of `invoke`.

# %%
async def stream_graph_updates(user_input: str):
    result = await mcp_graph.ainvoke(
        {"messages": [HumanMessage(content=user_input)]},
        config=config,
    )
    print("Assistant:", result["messages"][-1].content)


while True:
    try:
        user_input = input("User: ")
        if user_input.lower() in ["quit", "exit", "q"]:
            print("Goodbye!")
            break
        await stream_graph_updates(user_input)
    except Exception:
        # fallback if input() is not available (e.g. non-interactive run)
        user_input = "Get the todo list and summarize it."
        print("User: " + user_input)
        await stream_graph_updates(user_input)
        break
